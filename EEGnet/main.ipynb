# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ml_collections
# !pip install timm

# %%
import sys
sys.path.append("/content/drive/MyDrive/EEGnet/Code")
sys.path.append("/content/drive/MyDrive/EEGnet/Data")
sys.path.append("/content/drive/MyDrive/EEGnet/experiment")
sys.path.append("/content/drive/MyDrive/EEGnet")
sys.path.append("/content/drive/MyDrive/EEGnet/Code/kernels")
sys.path.append("/content/drive/MyDrive/EEGnet/Code/kernels/window_process")
